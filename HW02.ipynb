# %%
from google.colab import drive
drive.mount("/content/drive")
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/機器學習/467420-2023-03.csv")
df1=df[['氣溫(℃)','相對溼度(%)']]
name=['Temperature','RH']
df1.columns=name
df1=df1.drop(0)
df1
df1['Temperature']=df1['Temperature'].astype(float)
df1['RH']=df1['RH'].astype(int)
df1.plot(kind='scatter',x='Temperature',y='RH')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Temperature', ylabel='RH'>
